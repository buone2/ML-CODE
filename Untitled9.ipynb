# %% [markdown]
# <a href="https://colab.research.google.com/github/buone2/ML-CODE/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.metrics import mean_squared_error as mse

x = np.array([1, 4.5, 9, 10, 13])
y = np.array([0, 0.2, 2.5, 5.4, 7.3])
m, b = np.polyfit(x,y,1)
m = 0.5
b = 0

plt.figure(figsize=(8,5))
plt.scatter(x,y, color='r')
plt.title("5 data and regression line")
plt.plot(x,m*x + b)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
import matplotlib.pyplot as plt
from random import random

data=['[1.0,23.08],[0.9,15.86],[0.8,10.13],[0.7,5.89],[0.6,3.13],[0.5,1.85],[0.4,2.06],[0.3,3.75],[0.2,6.93][0.1,11.60]']
y=[23.08,15.86,10.13,5.89,3.13,1.85,2.06,3.75,6.93,11.60]
x=[1.0,0.9,0.8,0.7,0.6,0.5,0.4,0.3,0.2,0.1]

plt.figure(figsize=(8,5))
plt.plot(x,y)
plt.title("MSE optimization graph")
plt.xlabel("w")
plt.ylabel("mse")
plt.show()

# %%
x=np.random.rand(5)
y = 0.5 * x * 1.85

lin_reg = LinearRegression()
lin_reg.fit(x,y)
y_pred = lin_reg.predict(x)

plt.figure(figsize=(8,5))
plt.scatter(x,y, color='r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-589f45f0235c> in <module>()
#       2 y = 0.5 * x * 1.85
#       3
# ----> 4 lin_reg = LinearRegression()
#       5 lin_reg.fit(x,y)
#       6 y_pred = lin_reg.predict(x)
#
# NameError: name 'LinearRegression' is not defined
